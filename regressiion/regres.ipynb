# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
area=[2600,2800,3100,3400,3800]
price=[5600000,5800000,6100000,6600000,7200000]
plt.scatter(area,price,color='g')
plt.xlabel('area',size=15,color='r')
plt.ylabel('price',size=15,color='r')
plt.title('Area-price graph',color='r',size=20)
# Out:
# Text(0.5, 1.0, 'Area-price graph')
